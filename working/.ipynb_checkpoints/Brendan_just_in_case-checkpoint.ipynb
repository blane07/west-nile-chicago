# %% [markdown]
# # West Nile
# ### Starter Code

# %%
# Original code: Beating the Benchmark from West Nile Virus Prediction @ Kaggle by Abhihsek
# Modified by Brendan Lane
import pandas as pd
import numpy as np
from sklearn import ensemble, preprocessing

# %%
# Load dataset 
train = pd.read_csv('../assets/train.csv')
test = pd.read_csv('../assets/test.csv')
sample = pd.read_csv('../assets/sampleSubmission.csv')
weather = pd.read_csv('../assets/weather.csv')

# %%
train = train.drop_duplicates()
test = test.drop_duplicates()

# %%
# Output
y = train.WnvPresent.values

# %%
# Not using codesum for this benchmark
wx = weather.drop('CodeSum', axis=1)

# Split station 1 and 2 and join horizontally
wx1 = wx[wx['Station']==1]
wx2 = wx[wx['Station']==2]
wx1 = wx1.drop('Station', axis=1)
wx1 = wx2.drop('Station', axis=1)
wx = wx1.merge(wx2, on='Date', suffixes=('_1', '_2'))

# replace some missing values and T with nan
wx = wx.replace('M', np.nan)
wx = wx.replace('-', np.nan)
wx = wx.replace('T', np.nan)
wx = wx.replace(' T', np.nan)
wx = wx.replace('  T', np.nan)

# %%
# Functions to extract month and day from dataset
# You can also use parse_dates of Pandas.
def create_year(x):
    return(x.split('-')[0])

def create_month(x):
    return(x.split('-')[1])

def create_day(x):
    return(x.split('-')[2])

train['month'] = train.Date.apply(create_month)
train['day'] = train.Date.apply(create_day)
train['year'] = train.Date.apply(create_year)

test['month'] = test.Date.apply(create_month)
test['day'] = test.Date.apply(create_day)
test['year'] = test.Date.apply(create_year)

# %%
# Add integer latitude/longitude columns
train['Lat_int'] = train.Latitude.apply(int)
train['Long_int'] = train.Longitude.apply(int)
test['Lat_int'] = test.Latitude.apply(int)
test['Long_int'] = test.Longitude.apply(int)

# %%
# drop address columns
train = train.drop(['Address', 'AddressNumberAndStreet','WnvPresent', 'NumMosquitos'], axis = 1)
test = test.drop(['Id', 'Address', 'AddressNumberAndStreet'], axis = 1)

# %%
# Merge with weather data
train = train.merge(wx, on='Date')
test = test.merge(wx, on='Date')
train = train.drop(['Date', 'Block'], axis = 1)
test = test.drop(['Date', 'Block'], axis = 1)

# %%
train.head()
# Out:
#                   Species           Street  Trap   Latitude  Longitude  \
# 0  CULEX PIPIENS/RESTUANS   N OAK PARK AVE  T002  41.954690 -87.800991
# 1          CULEX RESTUANS   N OAK PARK AVE  T002  41.954690 -87.800991
# 2          CULEX RESTUANS    N MANDELL AVE  T007  41.994991 -87.769279
# 3  CULEX PIPIENS/RESTUANS     W FOSTER AVE  T015  41.974089 -87.824812
# 4          CULEX RESTUANS     W FOSTER AVE  T015  41.974089 -87.824812
#
#    AddressAccuracy month day  year  Lat_int     ...      Sunset_2  Depth_2  \
# 0                9    05  29  2007       41     ...           NaN      NaN
# 1                9    05  29  2007       41     ...           NaN      NaN
# 2                9    05  29  2007       41     ...           NaN      NaN
# 3                8    05  29  2007       41     ...           NaN      NaN
# 4                8    05  29  2007       41     ...           NaN      NaN
#
#    Water1_2 SnowFall_2  PrecipTotal_2  StnPressure_2 SeaLevel_2 ResultSpeed_2  \
# 0       NaN        NaN           0.00          29.44      30.09           5.8
# 1       NaN        NaN           0.00          29.44      30.09           5.8
# 2       NaN        NaN           0.00          29.44      30.09           5.8
# 3       NaN        NaN           0.00          29.44      30.09           5.8
# 4       NaN        NaN           0.00          29.44      30.09           5.8
#
#   ResultDir_2  AvgSpeed_2
# 0          16         7.4
# 1          16         7.4
# 2          16         7.4
# 3          16         7.4
# 4          16         7.4
#
# [5 rows x 50 columns]
